# %%
import cenpy

# %%
florida = cenpy.products.Decennial2010().from_state('Florida', level="block")
# Out:
# /Users/Simon/.conda/envs/cs109b/lib/python3.7/site-packages/pyproj/crs/crs.py:55: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /Users/Simon/.conda/envs/cs109b/lib/python3.7/site-packages/pyproj/crs/crs.py:55: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
florida.head()
# Out:
#              GEOID                                           geometry  \
# 0  120330038001331  POLYGON ((-9754426.490 3617665.460, -9754419.3...
# 1  120330038001454  POLYGON ((-9747103.670 3605761.210, -9747092.9...
# 2  120330038001883  POLYGON ((-9751945.060 3611802.080, -9751941.2...
# 3  120330038001881  POLYGON ((-9751516.820 3610812.760, -9751480.0...
# 4  120330038001846  POLYGON ((-9748366.700 3610745.090, -9748349.2...
#
#                                                 NAME state county   tract  \
# 0  Block 1331, Block Group 1, Census Tract 38, Es...    12    033  003800
# 1  Block 1454, Block Group 1, Census Tract 38, Es...    12    033  003800
# 2  Block 1883, Block Group 1, Census Tract 38, Es...    12    033  003800
# 3  Block 1881, Block Group 1, Census Tract 38, Es...    12    033  003800
# 4  Block 1846, Block Group 1, Census Tract 38, Es...    12    033  003800
#
#   block
# 0  1331
# 1  1454
# 2  1883
# 3  1881
# 4  1846

# %% [markdown]
# https://api.census.gov/data/2010/dec/sf1/variables.html
# This includes all the accessable variables, which can be specified like so,
# where
# H006002 = Average household size!!Renter occupied
# and
# P001001	= Total Population

# %%
florida = cenpy.products.Decennial2010().from_state('Florida', variables=['H006002', 'P001001'], level="block")
# Out:
# /Users/Simon/.conda/envs/cs109b/lib/python3.7/site-packages/pyproj/crs/crs.py:55: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /Users/Simon/.conda/envs/cs109b/lib/python3.7/site-packages/pyproj/crs/crs.py:55: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
florida
# Out:
#                  GEOID                                           geometry  \
# 0      120330038001331  POLYGON ((-9754426.490 3617665.460, -9754419.3...
# 1      120330038001454  POLYGON ((-9747103.670 3605761.210, -9747092.9...
# 2      120330038001883  POLYGON ((-9751945.060 3611802.080, -9751941.2...
# 3      120330038001881  POLYGON ((-9751516.820 3610812.760, -9751480.0...
# 4      120330038001846  POLYGON ((-9748366.700 3610745.090, -9748349.2...
# ...                ...                                                ...
# 95688  121079507001122  POLYGON ((-9089736.250 3459060.900, -9089718.4...
# 95689  121079507002082  POLYGON ((-9089771.870 3458758.600, -9089746.2...
# 95690  121079509005028  POLYGON ((-9090366.320 3455007.320, -9090340.2...
# 95691  121079509002003  POLYGON ((-9089737.360 3456180.360, -9089715.2...
# 95692  121079509005036  POLYGON ((-9090337.480 3454169.990, -9089806.4...
#
#        H006002  P001001                                               NAME  \
# ...
